# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

table_india = pd.read_html('https://en.wikipedia.org/wiki/Economy_of_India')

# %%
print(f'Total tables: {len(table_india)}')
# Out:
# Total tables: 21

# %%
table_india[2]
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0   1980                 371.9                        532.0
# 1   1981                 431.5                        603.2
# 2   1982                 474.1                        647.5
# 3   1983                 528.6                        705.3
# 4   1984                 568.6                        741.4
# 5   1985                 617.4                        787.1
# 6   1986                 659.9                        822.8
# 7   1987                 703.0                        857.7
# 8   1988                 797.9                        952.7
# 9   1989                 878.5                       1027.0
# 10  1990                 961.8                       1101.3
# 11  1991                1004.8                       1127.4
# 12  1992                1084.1                       1192.2
# 13  1993                1162.5                       1253.5
# 14  1994                1266.4                       1339.2
# ...

# %%
df=table_india[2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             48 non-null     int64
#  1   GDP (in Bil. US$PPP)             48 non-null     float64
#  2   GDP per capita (in US$ PPP)      48 non-null     float64
#  3   GDP (in Bil. US$nominal)         48 non-null     float64
#  4   GDP per capita (in US$ nominal)  48 non-null     float64
#  5   GDP growth (real)                48 non-null     object
#  6   Inflation rate (in Percent)      48 non-null     object
#  7   Unemployment (in Percent)        31 non-null     object
#  8   Government debt (in % of GDP)    37 non-null     object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.5+ KB

# %%
df.describe()
# Out:
#           Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# count    48.00             48.000000                    48.000000
# mean   2003.50           4794.875000                  3728.427083
# std      14.00           4758.258248                  3180.623347
# min    1980.00            371.900000                   532.000000
# 25%    1991.75           1064.275000                  1176.000000
# 50%    2003.50           2659.400000                  2372.400000
# 75%    2015.25           7303.600000                  5558.650000
# max    2027.00          17854.700000                 12151.500000
#
#        GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)
# count                 48.000000                        48.000000
# mean                1426.004167                      1110.554167
# std                 1435.591479                       957.798841
# min                  189.400000                       271.000000
# ...

# %%
df.isna().sum()
# Out:
# Year                                0
# GDP (in Bil. US$PPP)                0
# GDP per capita (in US$ PPP)         0
# GDP (in Bil. US$nominal)            0
# GDP per capita (in US$ nominal)     0
# GDP growth (real)                   0
# Inflation rate (in Percent)         0
# Unemployment (in Percent)          17
# Government debt (in % of GDP)      11
# dtype: int64

# %%
df.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 371.9                        532.0
# 1  1981                 431.5                        603.2
# 2  1982                 474.1                        647.5
# 3  1983                 528.6                        705.3
# 4  1984                 568.6                        741.4
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     189.4                            271.0
# 1                     196.5                            274.7
# 2                     203.5                            278.0
# 3                     222.0                            296.3
# 4                     215.6                            281.1
#
#   GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 0              5.3%                       11.3%                       NaN
# 1              6.0%                       12.7%                       NaN
# ...

# %%
df.tail()
# Out:
#     Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 43  2023               12813.1                       9025.5
# 44  2024               13972.9                       9754.5
# 45  2025               15196.8                      10516.7
# 46  2026               16497.4                      11320.5
# 47  2027               17854.7                      12151.5
#
#     GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 43                    3820.6                           2691.2
# 44                    4170.2                           2911.2
# 45                    4547.2                           3146.8
# 46                    4947.4                           3394.9
# 47                    5365.5                           3651.7
#
#    GDP growth (real) Inflation rate (in Percent) Unemployment (in Percent)  \
# 43              6.1%                        5.1%                       NaN
# 44              6.8%                        4.4%                       NaN
# ...

# %%
df.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in Percent)',
#        'Unemployment (in Percent)', 'Government debt (in % of GDP)'],
#       dtype='object')

# %%
df.rename(columns = {'inflation':'Inflation rate (in Percent)'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in Percent)',
#        'Unemployment (in Percent)', 'Government debt (in % of GDP)'],
#       dtype='object')

# %%
df['Inflation rate (in Percent)'].replace({'%':''}, regex=True).astype('float')
# Out:
# 0     11.3
# 1     12.7
# 2      7.7
# 3     12.6
# 4      6.5
# 5      6.3
# 6      8.9
# 7      9.1
# 8      7.2
# 9      4.6
# 10    11.2
# 11    13.5
# 12     9.9
# 13     7.3
# 14    10.3
# 15    10.0
# 16     9.4
# 17     6.8
# 18    13.1
# 19     5.7
# 20     3.8
# 21     4.3
# 22     4.0
# 23     3.9
# 24     3.8
# 25     4.4
# 26     6.7
# 27     6.2
# 28     9.1
# 29    12.3
# 30    10.5
# 31     9.5
# 32    10.0
# 33     9.4
# 34     5.8
# 35     4.9
# 36     4.5
# 37     3.6
# 38     3.4
# 39     4.8
# 40     6.2
# 41     5.5
# 42     6.9
# 43     5.1
# 44     4.4
# 45     4.1
# 46     4.0
# 47     4.0
# Name: Inflation rate (in Percent), dtype: float64

# %%
df = df.replace({'%': ''}, regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             48 non-null     int64
#  1   GDP (in Bil. US$PPP)             48 non-null     float64
#  2   GDP per capita (in US$ PPP)      48 non-null     float64
#  3   GDP (in Bil. US$nominal)         48 non-null     float64
#  4   GDP per capita (in US$ nominal)  48 non-null     float64
#  5   GDP growth (real)                48 non-null     object
#  6   Inflation rate (in Percent)      48 non-null     object
#  7   Unemployment (in Percent)        31 non-null     object
#  8   Government debt (in % of GDP)    37 non-null     object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 3.5+ KB

# %%
df["GDP growth (real)"] = pd.to_numeric(df["GDP growth (real)"])

# %%
df["Inflation rate (in Percent)"] = pd.to_numeric(df["Inflation rate (in Percent)"])

# %%
df["Unemployment (in Percent)"] = pd.to_numeric(df["Unemployment (in Percent)"])

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)', 'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)', 'GDP growth (real)', 'Inflation rate (in Percent)', 'Unemployment (in Percent)', 'Government debt (in\xa0% of GDP)']

# %%
df['Government debt (in\xa0% of GDP)']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11    75.3
# 12    77.4
# 13    77.0
# 14    73.5
# 15    69.7
# 16    66.0
# 17    67.8
# 18    68.1
# 19    70.0
# 20    73.6
# 21    78.7
# 22    82.9
# 23    84.4
# 24    83.4
# 25    81.0
# 26    77.2
# 27    74.1
# 28    72.8
# 29    71.5
# 30    66.4
# 31    68.6
# 32    68.0
# 33    67.7
# 34    67.1
# 35    69.0
# 36    68.9
# 37    69.7
# 38    70.4
# 39    75.1
# 40    89.2
# 41    84.2
# 42    83.4
# 43    83.8
# 44    84.1
# 45    83.8
# 46    83.4
# 47    83.0
# Name: Government debt (in % of GDP), dtype: object

# %%
df.rename(columns = {'Government debt (in\xa0% of GDP)':'Govt Debt)'}, inplace = True)

# %%
df.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in Percent)',
#        'Unemployment (in Percent)', 'Govt Debt)'],
#       dtype='object')

# %%
df.head()
# Out:
#    Year  GDP (in Bil. US$PPP)  GDP per capita (in US$ PPP)  \
# 0  1980                 371.9                        532.0
# 1  1981                 431.5                        603.2
# 2  1982                 474.1                        647.5
# 3  1983                 528.6                        705.3
# 4  1984                 568.6                        741.4
#
#    GDP (in Bil. US$nominal)  GDP per capita (in US$ nominal)  \
# 0                     189.4                            271.0
# 1                     196.5                            274.7
# 2                     203.5                            278.0
# 3                     222.0                            296.3
# 4                     215.6                            281.1
#
#    GDP growth (real)  Inflation rate (in Percent)  Unemployment (in Percent)  \
# 0                5.3                         11.3                        NaN
# 1                6.0                         12.7                        NaN
# ...

# %%
df.columns
# Out:
# Index(['Year', 'GDP (in Bil. US$PPP)', 'GDP per capita (in US$ PPP)',
#        'GDP (in Bil. US$nominal)', 'GDP per capita (in US$ nominal)',
#        'GDP growth (real)', 'Inflation rate (in Percent)',
#        'Unemployment (in Percent)', 'Govt Debt)'],
#       dtype='object')

# %%
plt.style.use('seaborn-whitegrid')
df.plot.line(x='Year', y=['Inflation rate (in Percent)', 'Unemployment (in Percent)'])
# Out:
# /tmp/ipykernel_232/2138333423.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# <AxesSubplot: xlabel='Year'>

# %%
#Step one: import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

#Step two: get the URL
url = 'https://www.basketball-reference.com/leagues/NBA_2020_totals.html'
req = requests.get(url)

#Step three: parse HTML page
soup = BeautifulSoup(req.content, 'html.parser')

#Step four: find the table
tabela = soup.find(name='table')

#Step five: from HTML Table to PANDAS DataFrame
df = pd.read_html(str(tabela))[0].set_index('Rk')
df.head()
# Out:
#                       Player Pos Age   Tm   G  GS    MP   FG  FGA   FG%  ...  \
# Rk                                                                       ...
# 1               Steven Adams   C  26  OKC  63  63  1680  283  478  .592  ...
# 2                Bam Adebayo  PF  22  MIA  72  72  2417  440  790  .557  ...
# 3          LaMarcus Aldridge   C  34  SAS  53  53  1754  391  793  .493  ...
# 4             Kyle Alexander   C  23  MIA   2   0    13    1    2  .500  ...
# 5   Nickeil Alexander-Walker  SG  21  NOP  47   1   591   98  266  .368  ...
#
#      FT%  ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# Rk
# 1   .582  207  376  583  146  51  67   94  122   684
# 2   .691  176  559  735  368  82  93  204  182  1146
# 3   .827  103  289  392  129  36  87   74  128  1001
# 4    NaN    2    1    3    0   0   0    1    1     2
# 5   .676    9   75   84   89  17   8   54   57   267
#
# [5 rows x 29 columns]

# %%
tabela

# %%
df=pd.read_html("https://www.icccricketschedule.com/ipl-2023-schedule-team-venue-time-table-pdf-point-table-ranking-winning-prediction")

# %%
df2=df[1]

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=74, step=1)

# %%
df2.columns
# Out:
# Index(['Match', 'IPL Teams', 'Date', 'Time (IST)'], dtype='object')

# %%
df2.set_index("Date", inplace=True)

# %%
df2
# Out:
#            Match    IPL Teams Time (IST)
# Date
# 25-Mar-23      1     GT vs RR    7:30 PM
# 26-Mar-23      2     DC vs MI    3:30 PM
# 26-Mar-23      3  PBKS vs RCB    7:30 PM
# 27-Mar-23      4   CSK vs LSG    7:30 PM
# 28-Mar-23      5   SRH vs KKR    7:30 PM
# ...          ...          ...        ...
# 21-May-23     70  SRH vs PBKS    7:30 PM
# TBD           71  QUALIFIER 1    7:30 PM
# TBD           72   ELIMINATOR    7:30 PM
# TBD           73  QUALIFIER 2    7:30 PM
# 28-May-23     74        FINAL    7:30 PM
#
# [74 rows x 3 columns]
